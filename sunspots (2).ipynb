# %% [markdown]
# # Sunspots Prediction Project
#
# This notebook is part of a **Machine Learning course on Udemy**, created as a **certification project**.
# It focuses on **time-series forecasting of sunspot activity** using **LSTM neural networks**.
#
# 📘 For full project details, theory, and results — see the [README.md](./README.md).

# %%
# Importing libraries

import matplotlib.pyplot as plt  #visualization
import seaborn as sns

import pandas as pd #data handling
import numpy as np

import tensorflow as tf #manipulation

import warnings #ignoring warnings
warnings.filterwarnings("ignore")

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # suppress TensorFlow warnings/errors
import tensorflow as tf

# %%
data= pd.read_csv("/kaggle/input/sunspots/Sunspots.csv")
data.head() #first 5 observations
# Out:
#    Unnamed: 0        Date  Monthly Mean Total Sunspot Number
# 0           0  1749-01-31                               96.7
# 1           1  1749-02-28                              104.3
# 2           2  1749-03-31                              116.7
# 3           3  1749-04-30                               92.8
# 4           4  1749-05-31                              141.7

# %%
data.tail() #last 5 observations (to check last year in data)
# Out:
#       Unnamed: 0        Date  Monthly Mean Total Sunspot Number
# 3260        3260  2020-09-30                                0.6
# 3261        3261  2020-10-31                               14.4
# 3262        3262  2020-11-30                               34.0
# 3263        3263  2020-12-31                               21.8
# 3264        3264  2021-01-31                               10.4

# %%
data.info() #general information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3265 entries, 0 to 3264
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         3265 non-null   int64
#  1   Date                               3265 non-null   object
#  2   Monthly Mean Total Sunspot Number  3265 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 76.7+ KB

# %% [markdown]
# * Total records: 3,265 months
# * Time span: January 1749 to January 2021
# * No null values found in the data

# %%
#last column- sunspot numbers
sunspots= data.iloc[:,-1]
sunspots.values
# Out:
# array([ 96.7, 104.3, 116.7, ...,  34. ,  21.8,  10.4])

# %% [markdown]
# **Visualizing the data**

# %%
# Visualizing the data - number of sunspots in each month
plt.figure(figsize=(28,6))
plt.plot(sunspots)
plt.ylabel(data.columns[-1], fontsize = 12, color = 'm')
plt.xlabel("Months from Jan 1749 to Jan 2021", fontsize = 12, color = 'm')
plt.title("Visualizing the Data", fontsize = 18, color = 'r', weight = 'bold')
plt.show()

# %% [markdown]
# * Each solar cycle lasts around 11 years, which is roughly 132 months.
# * The first official solar cycle began in 1755, but this dataset starts from 1749.
# * That means there are 6 extra years (about 72 months) of data before the first cycle began.
# * In the graph, this early part shows a decline in sunspot numbers, reaching a minimum before the first cycle starts.
# * The current solar cycle (Cycle 25) began in December 2019.
# * Since this dataset goes up to January 2021, there are about 13 months of data from this current cycle.

# %%
# Highlighting the period before the first cycle, the first cycle, and the current cycle

plt.figure(figsize=(28,6))
plt.plot(sunspots)            # The whole data
plt.plot(sunspots[:72])       # Data from 1749 till the beginning of the first cycle (72 months)
plt.plot(sunspots[72:72+132]) # The first cycle (11 months after the first 72 months)
plt.plot(sunspots[-13:])      # The current cycle
plt.ylabel(data.columns[-1], fontsize = 12, color = 'm')
plt.xlabel("Months from Jan 1749 to Jan 2021", fontsize = 12, color = 'm')
plt.title("Understanding the data", fontsize = 18, color = 'r', weight = 'bold')
plt.legend(["Full data", "Before 1755 - The first cycle", "The first cycle", "After 2019 - The currect cycle"], fontsize = 12)
plt.show()

# %%
years = []
start = 1755
for i in range(0, len(data.iloc[:,-1][72:]),132):
    years.append(start)
    start+=11

plt.figure(figsize = (28, 6))
plt.plot(sunspots[72:])
plt.title("Solar Cycle 1 till Solar Cycle 24", weight = 'bold', color = 'r', fontsize = 18)
plt.xlim(72, 3265-12)
plt.xticks(range(72, len(sunspots),132))
plt.gca().set_xticklabels(years) # replacing previous limits with calculated years 
plt.show()

# %% [markdown]
# * Some parts of the data don’t exactly match the official solar cycle records.
# * For example, the 4th solar cycle actually started in 1784, not 1788, and continued until 1798.
# * This small difference shows there’s a bit of mismatch between the dataset and historical records.
# * The data also looks a little noisy. A few points go as high as 400, even though the highest recorded sunspot count was 285 in March 1958 (Solar Cycle 19).
# * Since the data points are arranged in chronological order, this is a time series data.

# %% [markdown]
# # **Sequence Models for time series data - RNN, LSTM**

# %% [markdown]
# **Preparing functions for generating sequences of data and forecasting - Window method**

# %%
dum_series = sunspots[:10].values  # numpy array
dum_series, dum_series.shape       # array and its shape
# Out:
# (array([ 96.7, 104.3, 116.7,  92.8, 141.7, 139.2, 158. , 110.5, 126.5,
#         125.8]),
#  (10,))

# %% [markdown]
# This says that the array is one-dimensional

# %%
dum_series=dum_series[:, np.newaxis]   # shape now should be 10x1
dum_series, dum_series.shape
# Out:
# (array([[ 96.7],
#         [104.3],
#         [116.7],
#         [ 92.8],
#         [141.7],
#         [139.2],
#         [158. ],
#         [110.5],
#         [126.5],
#         [125.8]]),
#  (10, 1))

# %%
ds = tf.data.Dataset.from_tensor_slices(dum_series)  # Window method of tensorflow won't work on numpy array

# to display the content of the above dataset
for i in ds:
    for val in i:
        print(val)
# Out:
# tf.Tensor(96.7, shape=(), dtype=float64)
# tf.Tensor(104.3, shape=(), dtype=float64)
# tf.Tensor(116.7, shape=(), dtype=float64)
# tf.Tensor(92.8, shape=(), dtype=float64)
# tf.Tensor(141.7, shape=(), dtype=float64)
# tf.Tensor(139.2, shape=(), dtype=float64)
# tf.Tensor(158.0, shape=(), dtype=float64)
# tf.Tensor(110.5, shape=(), dtype=float64)
# tf.Tensor(126.5, shape=(), dtype=float64)
# tf.Tensor(125.8, shape=(), dtype=float64)

# %% [markdown]
# For the window method of tensorflow, to generate the sequence of LSTM, tensors are generated from numpy arrays.

# %%
# Generating sequence of length 3
window_size = 3                                               
ds = ds.window(window_size + 1, shift=1, drop_remainder=True) # drop remainder if True ensures the same shape of the tensor

for i in ds:
    for val in i:
        print(val)
# Out:
# tf.Tensor([96.7], shape=(1,), dtype=float64)
# tf.Tensor([104.3], shape=(1,), dtype=float64)
# tf.Tensor([116.7], shape=(1,), dtype=float64)
# tf.Tensor([92.8], shape=(1,), dtype=float64)
# tf.Tensor([104.3], shape=(1,), dtype=float64)
# tf.Tensor([116.7], shape=(1,), dtype=float64)
# tf.Tensor([92.8], shape=(1,), dtype=float64)
# tf.Tensor([141.7], shape=(1,), dtype=float64)
# tf.Tensor([116.7], shape=(1,), dtype=float64)
# tf.Tensor([92.8], shape=(1,), dtype=float64)
# tf.Tensor([141.7], shape=(1,), dtype=float64)
# tf.Tensor([139.2], shape=(1,), dtype=float64)
# tf.Tensor([92.8], shape=(1,), dtype=float64)
# tf.Tensor([141.7], shape=(1,), dtype=float64)
# tf.Tensor([139.2], shape=(1,), dtype=float64)
# tf.Tensor([158.], shape=(1,), dtype=float64)
# tf.Tensor([141.7], shape=(1,), dtype=float64)
# tf.Tensor([139.2], shape=(1,), dtype=float64)
# tf.Tensor([158.], shape=(1,), dtype=float64)
# tf.Tensor([110.5], shape=(1,), dtype=float64)
# tf.Tensor([139.2], shape=(1,), dtype=float64)
# tf.Tensor([158.], shape=(1,), dtype=float64)
# tf.Tensor([110.5], shape=(1,), dtype=float64)
# tf.Tensor([126.5], shape=(1,), dtype=float64)
# tf.Tensor([158.], shape=(1,), dtype=float64)
# tf.Tensor([110.5], shape=(1,), dtype=float64)
# tf.Tensor([126.5], shape=(1,), dtype=float64)
# tf.Tensor([125.8], shape=(1,), dtype=float64)

# %% [markdown]
# For example, Previous 3 values will be used to train the model to learn and predict the 4th value.

# %%
ds = ds.flat_map(lambda w: w.batch(window_size + 1)) # batch of 4 is generated
ds = ds.map(lambda w: (w[:-1], w[-1]))               # two different outputs are generated (3 and 1)

for i in ds:
    for val in i:
        print(val)
# Out:
# tf.Tensor(
# [[ 96.7]
#  [104.3]
#  [116.7]], shape=(3, 1), dtype=float64)
# tf.Tensor([92.8], shape=(1,), dtype=float64)
# tf.Tensor(
# [[104.3]
#  [116.7]
#  [ 92.8]], shape=(3, 1), dtype=float64)
# tf.Tensor([141.7], shape=(1,), dtype=float64)
# tf.Tensor(
# [[116.7]
#  [ 92.8]
#  [141.7]], shape=(3, 1), dtype=float64)
# tf.Tensor([139.2], shape=(1,), dtype=float64)
# tf.Tensor(
# [[ 92.8]
#  [141.7]
#  [139.2]], shape=(3, 1), dtype=float64)
# tf.Tensor([158.], shape=(1,), dtype=float64)
# tf.Tensor(
# [[141.7]
#  [139.2]
#  [158. ]], shape=(3, 1), dtype=float64)
# tf.Tensor([110.5], shape=(1,), dtype=float64)
# tf.Tensor(
# [[139.2]
#  [158. ]
#  [110.5]], shape=(3, 1), dtype=float64)
# tf.Tensor([126.5], shape=(1,), dtype=float64)
# tf.Tensor(
# [[158. ]
#  [110.5]
#  [126.5]], shape=(3, 1), dtype=float64)
# tf.Tensor([125.8], shape=(1,), dtype=float64)

# %% [markdown]
# Batches of 4 are generated (3 input data and one predicted value)

# %%
ds = ds.batch(10).prefetch(1)  

for i in ds:
    for val in i:
        print(val)
    print("\n")
# Out:
# tf.Tensor(
# [[[ 96.7]
#   [104.3]
#   [116.7]]
#
#  [[104.3]
#   [116.7]
#   [ 92.8]]
#
#  [[116.7]
#   [ 92.8]
#   [141.7]]
#
#  [[ 92.8]
#   [141.7]
#   [139.2]]
#
#  [[141.7]
#   [139.2]
#   [158. ]]
#
#  [[139.2]
#   [158. ]
#   [110.5]]
#
#  [[158. ]
#   [110.5]
#   [126.5]]], shape=(7, 3, 1), dtype=float64)
# tf.Tensor(
# [[ 92.8]
#  [141.7]
#  [139.2]
#  [158. ]
#  [110.5]
#  [126.5]
#  [125.8]], shape=(7, 1), dtype=float64)

# %% [markdown]
# * This is the final 3D data with sequence length of 3.
# * Since there are 10 elements, maximum batch size is 7.
# * Also, shape(7,3,1) implies shape(batch size, sequence length, features using which the prediction takes place)

# %%
#compiling all the generating functions defined above to train the helper fucntion
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = series[:, np.newaxis]                                # adding new axis(dimension) to array
    ds = tf.data.Dataset.from_tensor_slices(series)               # converting numpy array to tensor in order to use window of tensor flow
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True) # creating window
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))          # flattening batches as datasets of their elements (input elements)
    ds = ds.shuffle(shuffle_buffer)                               # to reduce the variance and overfits
    ds = ds.map(lambda w: (w[:-1], w[-1]))                        # now this window has the input value from which the future value has to be predicted followed by the future value
    return ds.batch(batch_size).prefetch(1)                       # prefetching one batch of data, also makes sure one batch is ready next

# %%
def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(batch_size).prefetch(1)
    forecast = model.predict(ds)  # to predict
    return forecast

# %% [markdown]
# Here, window size does not include a +1 because this model is going to be trained to predict the next value.

# %%
#data preparation
series = data['Monthly Mean Total Sunspot Number'].values
time = data['Unnamed: 0'].values

# splitting the data into train and test
split_time = int(len(series)*0.9)          # 90% of the original data is for training
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]
print(f"There are {len(x_train)} training samples and {len(x_valid)} validation samples.")

# Parameters
delta = 1                      # Huber loss
window_size = 60              
batch_size = 145              
shuffle_buffer_size= 900       # shuffling the dataset randomly
epochs = 100                   # for optimal learning rate
train_epochs = epochs + 100    # training epochs
momentum_sgd = 0.9             # for optimizer
# Out:
# There are 2938 training samples and 327 validation samples.

# %% [markdown]
# * Here, as an example, 90% of the original data is used as training sample which will be used to predict the remaining values.
# The values predicted will be validated by the validation samples(remaining 10%)
# * Hubber loss is chosen since it is less sensitive to outliers in the data.

# %% [markdown]
# **Building the model and finding the best learning rate to optimize model training**

# %%
#clearing previous model data
tf.keras.backend.clear_session()

# to make sure results are same everytime the notebook is run
tf.random.set_seed(42)
np.random.seed(42)

# calling the window_dataset function to generate the training data
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# model
model = tf.keras.models.Sequential([
#a stack of layers
  tf.keras.layers.Conv1D(filters=132, kernel_size=4,strides=1, padding="causal", activation="relu",input_shape=[None, 1]), #smoothens the input (noise reduction)
  tf.keras.layers.LSTM(256, return_sequences=True), # returns output for all cycles
  tf.keras.layers.LSTM(132, return_sequences=False),# reutrns output only the last time
  tf.keras.layers.Dense(80, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1), # outputs go through all these dense layers those many times and final output is predicted
  tf.keras.layers.Lambda(lambda x: x * 400) #to scale the data back into the same range as the real data (from visulaized data)
])

model.summary()

#it changes the learning rate gradually during training to see what works best.
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20), verbose = 0) #  starting lr * 10^(0/20), starting lr * 10^(1/20), so on..

# using Stochastic Gradient Desect (STG) as the optimizer tells TensorFlow how to train the model
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-8, momentum=momentum_sgd) #updates weights slowly, based on small batches of data
model.compile(loss=tf.keras.losses.Huber(delta),
              optimizer=optimizer,
              metrics=["mae"]) # applying Huber loss
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, None, 132)      │           660 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, None, 256)      │       398,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 132)            │       205,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 80)             │        10,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           810 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 615,849 (2.35 MB)
#  Trainable params: 615,849 (2.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_set, epochs=epochs, callbacks=[lr_schedule]) # to track the history of training
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 112.5679 - mae: 113.0679 - learning_rate: 1.0000e-08
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 98.7076 - mae: 99.2073 - learning_rate: 1.1220e-08
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 86.7031 - mae: 87.2018 - learning_rate: 1.2589e-08
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 79.7135 - mae: 80.2116 - learning_rate: 1.4125e-08
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 78.4348 - mae: 78.9327 - learning_rate: 1.5849e-08
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 76.3074 - mae: 76.8054 - learning_rate: 1.7783e-08
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 74.9401 - mae: 75.4381 - learning_rate: 1.9953e-08
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 73.1733 - mae: 73.6702 - learning_rate: 2.2387e-08
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 73.1884 - mae: 73.6848 - learning_rate: 2.5119e-08
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 71.7973 - mae: 72.2919 - learning_rate: 2.8184e-08
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 71.7263 - mae: 72.2229 - learning_rate: 3.1623e-08
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 70.9733 - mae: 71.4701 - learning_rate: 3.5481e-08
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 69.9843 - mae: 70.4802 - learning_rate: 3.9811e-08
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 67.9546 - mae: 68.4513 - learning_rate: 4.4668e-08
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 65.2703 - mae: 65.7663 - learning_rate: 5.0119e-08
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 66.1965 - mae: 66.6938 - learning_rate: 5.6234e-08
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 64.5025 - mae: 64.9997 - learning_rate: 6.3096e-08
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 64.5435 - mae: 65.0400 - learning_rate: 7.0795e-08
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 63.0518 - mae: 63.5496 - learning_rate: 7.9433e-08
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 59.8898 - mae: 60.3865 - learning_rate: 8.9125e-08
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 59.6957 - mae: 60.1936 - learning_rate: 1.0000e-07
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 56.2168 - mae: 56.7142 - learning_rate: 1.1220e-07
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 55.6326 - mae: 56.1312 - learning_rate: 1.2589e-07
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 54.1173 - mae: 54.6156 - learning_rate: 1.4125e-07
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 52.8667 - mae: 53.3635 - learning_rate: 1.5849e-07
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 51.0962 - mae: 51.5936 - learning_rate: 1.7783e-07
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 48.6817 - mae: 49.1777 - learning_rate: 1.9953e-07
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 48.2552 - mae: 48.7534 - learning_rate: 2.2387e-07
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 46.6283 - mae: 47.1259 - learning_rate: 2.5119e-07
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 42.1287 - mae: 42.6252 - learning_rate: 2.8184e-07
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 37.4183 - mae: 37.9147 - learning_rate: 3.1623e-07
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 34.3530 - mae: 34.8489 - learning_rate: 3.5481e-07
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 31.5256 - mae: 32.0204 - learning_rate: 3.9811e-07
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 29.0021 - mae: 29.4948 - learning_rate: 4.4668e-07
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 26.6616 - mae: 27.1550 - learning_rate: 5.0119e-07
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 25.8160 - mae: 26.3095 - learning_rate: 5.6234e-07
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 24.1636 - mae: 24.6569 - learning_rate: 6.3096e-07
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 22.3035 - mae: 22.7981 - learning_rate: 7.0795e-07
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 20.9478 - mae: 21.4398 - learning_rate: 7.9433e-07
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 20.5803 - mae: 21.0716 - learning_rate: 8.9125e-07
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 20.4642 - mae: 20.9561 - learning_rate: 1.0000e-06
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.6345 - mae: 20.1264 - learning_rate: 1.1220e-06
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.1260 - mae: 19.6179 - learning_rate: 1.2589e-06
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.0935 - mae: 19.5875 - learning_rate: 1.4125e-06
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.9332 - mae: 20.4266 - learning_rate: 1.5849e-06
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 18.4831 - mae: 18.9728 - learning_rate: 1.7783e-06
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.3238 - mae: 18.8151 - learning_rate: 1.9953e-06
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 17.8854 - mae: 18.3786 - learning_rate: 2.2387e-06
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 17.9966 - mae: 18.4870 - learning_rate: 2.5119e-06
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.6272 - mae: 18.1188 - learning_rate: 2.8184e-06
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.5238 - mae: 19.0184 - learning_rate: 3.1623e-06
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.8657 - mae: 18.3566 - learning_rate: 3.5481e-06
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.4177 - mae: 17.9087 - learning_rate: 3.9811e-06
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.3477 - mae: 17.8386 - learning_rate: 4.4668e-06
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 17.0496 - mae: 17.5429 - learning_rate: 5.0119e-06
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.6753 - mae: 18.1662 - learning_rate: 5.6234e-06
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.0767 - mae: 18.5689 - learning_rate: 6.3096e-06
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.3358 - mae: 17.8283 - learning_rate: 7.0795e-06
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.5387 - mae: 20.0321 - learning_rate: 7.9433e-06
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.8739 - mae: 18.3677 - learning_rate: 8.9125e-06
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.1118 - mae: 18.6061 - learning_rate: 1.0000e-05
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 20.5473 - mae: 21.0412 - learning_rate: 1.1220e-05
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 18.7129 - mae: 19.2073 - learning_rate: 1.2589e-05
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.6579 - mae: 18.1495 - learning_rate: 1.4125e-05
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.6217 - mae: 20.1141 - learning_rate: 1.5849e-05
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 18.3798 - mae: 18.8735 - learning_rate: 1.7783e-05
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 21.5520 - mae: 22.0446 - learning_rate: 1.9953e-05
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.2645 - mae: 19.7581 - learning_rate: 2.2387e-05
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.0995 - mae: 18.5928 - learning_rate: 2.5119e-05
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.0440 - mae: 17.5342 - learning_rate: 2.8184e-05
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.3561 - mae: 19.8494 - learning_rate: 3.1623e-05
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.3424 - mae: 18.8340 - learning_rate: 3.5481e-05
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.1677 - mae: 19.6613 - learning_rate: 3.9811e-05
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 24.1299 - mae: 24.6234 - learning_rate: 4.4668e-05
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 21.7597 - mae: 22.2557 - learning_rate: 5.0119e-05
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 17.6056 - mae: 18.0955 - learning_rate: 5.6234e-05
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 19.9163 - mae: 20.4103 - learning_rate: 6.3096e-05
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 23.8774 - mae: 24.3713 - learning_rate: 7.0795e-05
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 21.4531 - mae: 21.9483 - learning_rate: 7.9433e-05
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 21.2652 - mae: 21.7573 - learning_rate: 8.9125e-05
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 23.3712 - mae: 23.8661 - learning_rate: 1.0000e-04
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.5101 - mae: 19.0037 - learning_rate: 1.1220e-04
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 23.0934 - mae: 23.5875 - learning_rate: 1.2589e-04
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 21.9699 - mae: 22.4658 - learning_rate: 1.4125e-04
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 22.9386 - mae: 23.4328 - learning_rate: 1.5849e-04
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 20.0361 - mae: 20.5291 - learning_rate: 1.7783e-04
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 27.7109 - mae: 28.2063 - learning_rate: 1.9953e-04
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 40.1229 - mae: 40.6200 - learning_rate: 2.2387e-04
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 76.7010 - mae: 77.1994 - learning_rate: 2.5119e-04
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 52.5684 - mae: 53.0663 - learning_rate: 2.8184e-04
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 56.4428 - mae: 56.9420 - learning_rate: 3.1623e-04
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 57.4352 - mae: 57.9340 - learning_rate: 3.5481e-04
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 54.7602 - mae: 55.2586 - learning_rate: 3.9811e-04
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 52.2450 - mae: 52.7434 - learning_rate: 4.4668e-04
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 79.3262 - mae: 79.8256 - learning_rate: 5.0119e-04
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 63.1669 - mae: 63.6652 - learning_rate: 5.6234e-04
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 54.5489 - mae: 55.0475 - learning_rate: 6.3096e-04
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 59.6198 - mae: 60.1169 - learning_rate: 7.0795e-04
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 52.3605 - mae: 52.8582 - learning_rate: 7.9433e-04
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 58.3174 - mae: 58.8157 - learning_rate: 8.9125e-04

# %%
# learning rates used above
lrs = 1e-8 * (10**(np.arange(epochs)/20))
lrs
# Out:
# array([1.00000000e-08, 1.12201845e-08, 1.25892541e-08, 1.41253754e-08,
#        1.58489319e-08, 1.77827941e-08, 1.99526231e-08, 2.23872114e-08,
#        2.51188643e-08, 2.81838293e-08, 3.16227766e-08, 3.54813389e-08,
#        3.98107171e-08, 4.46683592e-08, 5.01187234e-08, 5.62341325e-08,
#        6.30957344e-08, 7.07945784e-08, 7.94328235e-08, 8.91250938e-08,
#        1.00000000e-07, 1.12201845e-07, 1.25892541e-07, 1.41253754e-07,
#        1.58489319e-07, 1.77827941e-07, 1.99526231e-07, 2.23872114e-07,
#        2.51188643e-07, 2.81838293e-07, 3.16227766e-07, 3.54813389e-07,
#        3.98107171e-07, 4.46683592e-07, 5.01187234e-07, 5.62341325e-07,
#        6.30957344e-07, 7.07945784e-07, 7.94328235e-07, 8.91250938e-07,
#        1.00000000e-06, 1.12201845e-06, 1.25892541e-06, 1.41253754e-06,
#        1.58489319e-06, 1.77827941e-06, 1.99526231e-06, 2.23872114e-06,
#        2.51188643e-06, 2.81838293e-06, 3.16227766e-06, 3.54813389e-06,
#        3.98107171e-06, 4.46683592e-06, 5.01187234e-06, 5.62341325e-06,
#        6.30957344e-06, 7.07945784e-06, 7.94328235e-06, 8.91250938e-06,
#        1.00000000e-05, 1.12201845e-05, 1.25892541e-05, 1.41253754e-05,
#        1.58489319e-05, 1.77827941e-05, 1.99526231e-05, 2.23872114e-05,
#        2.51188643e-05, 2.81838293e-05, 3.16227766e-05, 3.54813389e-05,
#        3.98107171e-05, 4.46683592e-05, 5.01187234e-05, 5.62341325e-05,
#        6.30957344e-05, 7.07945784e-05, 7.94328235e-05, 8.91250938e-05,
#        1.00000000e-04, 1.12201845e-04, 1.25892541e-04, 1.41253754e-04,
#        1.58489319e-04, 1.77827941e-04, 1.99526231e-04, 2.23872114e-04,
#        2.51188643e-04, 2.81838293e-04, 3.16227766e-04, 3.54813389e-04,
#        3.98107171e-04, 4.46683592e-04, 5.01187234e-04, 5.62341325e-04,
#        6.30957344e-04, 7.07945784e-04, 7.94328235e-04, 8.91250938e-04])

# %%
# to find the optimal learning rate
min_loss = min(history.history['loss']) #minimum loss
idx_min_loss = history.history['loss'].index(min_loss) #index of minimum loss
opt_lr = lrs[idx_min_loss] # learning rate corresponding to minimum loss
first = str(round(float(str(opt_lr).split('e')[0]))) #rounding off lr
second = str(opt_lr).split('e')[-1]
final = [first, second]
x = "e".join(final)
x = float(x)
print(f"Optimal Learning Rate was {x}.")
# Out:
# Optimal Learning Rate was 5e-06.

# %%
# plotting Losses vs Learning Rates
fig = plt.figure(figsize=(15, 6))
plt.semilogx(lrs, history.history["loss"]) #learning rates increase exponentially. So, plotting them on a logarithmic scale gives a clear curve.
plt.grid(True, ls="--")
plt.plot(opt_lr,min_loss, color = 'r', marker = 'x', markersize = 7)
plt.title(f"Optimum Learning Rate", color = 'm', fontsize = 15)
plt.ylabel("Losses", fontsize = 13, color = 'g')
plt.xlabel("Learining Rates", fontsize = 13, color = 'g')
plt.annotate(f"lr = {x}", (opt_lr,min_loss+2), (opt_lr+0.05e-5, min_loss+15), arrowprops = dict(facecolor ='k', width = 2, headwidth = 8), fontsize = 12) #highlighting the best lr on the graph
plt.show()

# %%
# Using the same steps to build the model but now with the optimal learning rate to train it
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=132, kernel_size=4,strides=1, padding="causal", activation="relu",input_shape=[None, 1]),
  tf.keras.layers.LSTM(256, return_sequences=True),
  tf.keras.layers.LSTM(132, return_sequences=False),
  tf.keras.layers.Dense(80, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])

optimizer = tf.keras.optimizers.SGD(learning_rate=opt_lr, momentum=momentum_sgd)
model.compile(loss=tf.keras.losses.Huber(delta),
              optimizer=optimizer,
              metrics=["mae"])

history = model.fit(train_set,epochs=train_epochs)
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 98.4169 - mae: 98.9149
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 35.6707 - mae: 36.1681
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 20.5097 - mae: 21.0018
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.5202 - mae: 20.0136
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.6350 - mae: 19.1266
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.0186 - mae: 18.5104
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.9893 - mae: 18.4795
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.2951 - mae: 18.7888
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.7266 - mae: 20.2204
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.7575 - mae: 18.2494
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.8302 - mae: 18.3218
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.0007 - mae: 18.4928
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.8235 - mae: 18.3157
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.5644 - mae: 19.0547
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 19.3707 - mae: 19.8655
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.6661 - mae: 19.1595
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.3145 - mae: 17.8065
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.1575 - mae: 17.6490
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.4529 - mae: 17.9445
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.0879 - mae: 18.5793
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.3021 - mae: 17.7934
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.2098 - mae: 17.7016
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 17.3157 - mae: 17.8085
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.2014 - mae: 17.6933
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.8010 - mae: 18.2933
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.8077 - mae: 18.3013
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.9330 - mae: 17.4235
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.9092 - mae: 18.3994
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.5210 - mae: 18.0130
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.9313 - mae: 17.4222
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.0732 - mae: 18.5665
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.6289 - mae: 18.1220
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 17.8386 - mae: 18.3313
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.2646 - mae: 17.7559
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.8197 - mae: 17.3113
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 17.3402 - mae: 17.8324
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.7550 - mae: 17.2448
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.7478 - mae: 17.2380
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.7074 - mae: 17.1995
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.3831 - mae: 17.8747
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.4401 - mae: 17.9342
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.1992 - mae: 17.6920
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.6730 - mae: 18.1663
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.0453 - mae: 17.5377
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.0304 - mae: 17.5222
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.6245 - mae: 17.1153
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.7620 - mae: 17.2528
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3846 - mae: 16.8775
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4037 - mae: 16.8954
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.6355 - mae: 17.1258
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 17.3131 - mae: 17.8046
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.8565 - mae: 17.3461
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.6031 - mae: 18.0935
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.9772 - mae: 17.4680
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.8433 - mae: 17.3353
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.6243 - mae: 17.1142
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.9644 - mae: 17.4543
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.7918 - mae: 17.2838
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5557 - mae: 17.0450
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2490 - mae: 16.7411
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5785 - mae: 17.0689
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.3936 - mae: 17.8865
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.8860 - mae: 17.3763
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5572 - mae: 17.0485
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.0400 - mae: 17.5312
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.1271 - mae: 17.6189
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2026 - mae: 16.6931
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2166 - mae: 16.7057
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 16.4142 - mae: 16.9030
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4321 - mae: 16.9230
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.8246 - mae: 17.3137
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5301 - mae: 17.0217
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.6501 - mae: 17.1413
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.0762 - mae: 17.5608
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.7412 - mae: 17.2332
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5900 - mae: 17.0818
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2874 - mae: 16.7774
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 16.2360 - mae: 16.7252
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 16.2111 - mae: 16.7003
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.0534 - mae: 16.5448
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2770 - mae: 16.7673
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.6411 - mae: 17.1306
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.9825 - mae: 16.4719
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2710 - mae: 16.7605
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5505 - mae: 17.0418
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.7215 - mae: 17.2128
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 16.4627 - mae: 16.9542
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 15.9837 - mae: 16.4734
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.9776 - mae: 17.4680
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.6980 - mae: 18.1903
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.1270 - mae: 17.6182
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.8835 - mae: 17.3729
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5367 - mae: 17.0291
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5164 - mae: 17.0087
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.6151 - mae: 17.1049
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.8322 - mae: 17.3235
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.4694 - mae: 17.9635
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.6717 - mae: 17.1637
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.8290 - mae: 17.3206
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.0963 - mae: 16.5878
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2988 - mae: 16.7889
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4621 - mae: 16.9517
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2320 - mae: 16.7227
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4555 - mae: 16.9444
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5346 - mae: 17.0249
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4665 - mae: 16.9596
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5894 - mae: 17.0807
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.6129 - mae: 17.1030
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3593 - mae: 16.8510
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.0814 - mae: 16.5701
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2034 - mae: 16.6936
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.1576 - mae: 17.6487
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3003 - mae: 16.7921
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3963 - mae: 16.8877
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 16.3139 - mae: 16.8038
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3907 - mae: 16.8811
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 17.0218 - mae: 17.5111
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.9413 - mae: 17.4301
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3468 - mae: 16.8399
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2568 - mae: 16.7459
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 16.2670 - mae: 16.7549
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 16.7681 - mae: 17.2595
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 16.4470 - mae: 16.9360
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.7870 - mae: 16.2764
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2360 - mae: 16.7253
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4920 - mae: 16.9811
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2441 - mae: 16.7338
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.1147 - mae: 16.6041
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5874 - mae: 17.0764
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3105 - mae: 16.8018
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.8627 - mae: 16.3502
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3116 - mae: 16.8019
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3349 - mae: 16.8249
# Epoch 134/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.4647 - mae: 17.9572
# Epoch 135/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.1308 - mae: 16.6214
# Epoch 136/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.0358 - mae: 16.5269
# Epoch 137/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4698 - mae: 16.9591
# Epoch 138/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4282 - mae: 16.9174
# Epoch 139/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4258 - mae: 16.9154
# Epoch 140/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 16.5156 - mae: 17.0053
# Epoch 141/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.9534 - mae: 16.4406
# Epoch 142/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.8540 - mae: 16.3430
# Epoch 143/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.1104 - mae: 16.6001
# Epoch 144/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.9432 - mae: 16.4340
# Epoch 145/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.6796 - mae: 16.1665
# Epoch 146/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.7874 - mae: 17.2785
# Epoch 147/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.9326 - mae: 17.4211
# Epoch 148/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.0704 - mae: 16.5595
# Epoch 149/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2397 - mae: 16.7292
# Epoch 150/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3257 - mae: 16.8133
# Epoch 151/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.1907 - mae: 16.6799
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.9149 - mae: 16.4055
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3408 - mae: 16.8313
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3231 - mae: 16.8128
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.9674 - mae: 16.4567
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.0554 - mae: 16.5443
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.9355 - mae: 16.4246
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2350 - mae: 16.7238
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.8427 - mae: 16.3321
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.6209 - mae: 16.1119
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.0459 - mae: 16.5352
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.8553 - mae: 16.3452
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.1152 - mae: 16.6042
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.1941 - mae: 17.6829
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3763 - mae: 16.8665
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.7691 - mae: 16.2594
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.0180 - mae: 17.5095
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2035 - mae: 16.6937
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.0633 - mae: 16.5520
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.6986 - mae: 16.1877
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.7173 - mae: 16.2064
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.5496 - mae: 16.0390
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4242 - mae: 16.9163
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4987 - mae: 16.9891
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2627 - mae: 16.7540
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3318 - mae: 16.8216
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3311 - mae: 16.8211
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.0667 - mae: 16.5567
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.1601 - mae: 16.6492
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.6912 - mae: 16.1823
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 15.6644 - mae: 16.1514
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5708 - mae: 17.0608
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.5723 - mae: 17.0629
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.3149 - mae: 16.8073
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4123 - mae: 16.9030
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.1140 - mae: 16.6055
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.6942 - mae: 17.1848
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.6338 - mae: 17.1249
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2135 - mae: 16.7050
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.1524 - mae: 16.6414
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4829 - mae: 16.9751
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.8690 - mae: 16.3580
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.6837 - mae: 16.1729
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.7446 - mae: 16.2344
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.4817 - mae: 16.9747
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.8389 - mae: 17.3313
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.7969 - mae: 16.2868
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.9443 - mae: 16.4338
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 15.6389 - mae: 16.1251
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 16.2601 - mae: 16.7510

# %%
# fetching the MAE and Huber Loss from the history
mae=history.history['mae']
loss=history.history['loss']

# plotting
fig = plt.figure(figsize=(15, 6))
plt.plot(mae, 'r')
plt.plot(loss, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.legend(["MAE", "Loss"])

# %%
#calling the function 
rnn_forecast = model_forecast(model, series[:, np.newaxis], window_size)
rnn_forecast = rnn_forecast[split_time - window_size:-1, 0]  # rnn_forecast[-328:-1, 0]

# plotting original data vs predicted values
plt.figure(figsize=(15, 6))
plt.plot(time_valid, x_valid)
plt.plot(time_valid, rnn_forecast)
plt.title("")
plt.legend(["Validation Data", "Predicted Data"])
plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step

# %%
# validation MAE
val_mae=tf.keras.metrics.mae(x_valid, rnn_forecast).numpy()
print(f"MAE on the validation data:- {val_mae}")
# Out:
# MAE on the validation data:- 12.911198616027832

# %% [markdown]
# # **-------------------------------------------------------------------------------------**
